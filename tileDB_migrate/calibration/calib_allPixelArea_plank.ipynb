# %%
import mysql.connector
import numpy as np
import pandas as pd
import zarr
import os
import matplotlib.pyplot as plt
PI = np.pi
SIGMA = 5.670373e-8

# %%
HEIGHT = 256
WIDTH = 384

# %%
def blackbody_planck(T):
    T = np.asarray(T)
    result = np.where(T > 0, SIGMA * np.power(T, 4) / PI, 0.0)
    return result if result.ndim > 0 else float(result)

# %%
base_dir = "/Volumes/Transcend/zarrDB"
zarr_path = os.path.join(base_dir, "Haya2TIR.zarr")

# %%
base_dir = "/Volumes/Transcend/zarrDB"
zarr_path = os.path.join(base_dir, "Haya2TIR.zarr")

# MySQL 接続
conn = mysql.connector.connect(
    user="root",
    password="",
    unix_socket="/tmp/mysql_database_dev.sock",
    database="heat_db",
)
cur = conn.cursor(dictionary=True)

# %%
cur.execute("SELECT * FROM tirimageinfo")
df = pd.DataFrame(cur.fetchall())
cur.close()
conn.close()

# %%
print(df.columns)
base_dir = "/Users/kengokakazu/研究用/HEAT/tileDB_migrate/zarrDB"
zarr_path = os.path.join(base_dir, "tirimageinfo.zarr")
# Out:
# Index(['img_file', 'thumbnail', 'path', 'date_time', 'm', 'place',
#        'target_name', 'phi', 'hood_t', 'target_t', 'len_t', 'plt_t', 'bol_t',
#        'img_id', 'plt_t_set', 'bol_t_mon', 'pkg_t_mon', 'case_t_mon',
#        'sh_t_mon', 'lens_t_mon'],
#       dtype='object')

# %%
root = zarr.open(zarr_path, mode="r")
pixel = root["pixel"]
pixel_modified = root["pixel_modified"]
mask = root["mask"]
filename_df = pd.read_csv(os.path.join(base_dir, "file_index_mapping.csv"))
pixel_area = [(x, y) for x in range(32) for y in range(32)]

# %%
weight_avg = np.zeros((HEIGHT,WIDTH,6))
intercept_avg = np.zeros((HEIGHT,WIDTH))

# %%
for x,y in pixel_area:
    m = filename_df.merge(df, left_on="filename", right_on="img_file", how="left")
    m = m.sort_values("file_idx")
    target_t = m["target_t"].to_numpy()
    vy = np.asarray(pixel_modified[:, y, x])   
    vx_df = m[["target_t", "bol_t_mon", "pkg_t_mon", "case_t_mon", "sh_t_mon", "lens_t_mon"]].rename(columns={"bol_t_mon":"bol_t","pkg_t_mon":"pkg_t","case_t_mon":"case_t","sh_t_mon":"sh_t","lens_t_mon":"lens_t"})     
    K_OFFSET = 273.15
    header = vx_df.columns.tolist()
    for c in header:
        vx_df[c] = vx_df[c] + K_OFFSET
    features = vx_df.columns.tolist()
    rng = np.random.default_rng(42)
    vx = vx_df.to_numpy()
    vx = blackbody_planck(vx)
    vx_aug = np.hstack([vx, np.ones((vx.shape[0], 1))])  
    w,residuals,rank,s = np.linalg.lstsq(vx_aug,vy)
    coef = w[:-1]
    intercept = w[-1]
    weight_avg[y,x,:] = coef
    intercept_avg[y,x] = intercept
    print("pixel: ", x, y,"finished")
# Out:
# pixel:  0 0 finished
# pixel:  0 1 finished
# pixel:  0 2 finished
# pixel:  0 3 finished
# pixel:  0 4 finished
# pixel:  0 5 finished
# pixel:  0 6 finished
# pixel:  0 7 finished
# pixel:  0 8 finished
# pixel:  0 9 finished
# pixel:  0 10 finished
# pixel:  0 11 finished
# pixel:  0 12 finished
# pixel:  0 13 finished
# pixel:  0 14 finished
# pixel:  0 15 finished
# pixel:  0 16 finished
# pixel:  0 17 finished
# pixel:  0 18 finished
# pixel:  0 19 finished
# pixel:  0 20 finished
# pixel:  0 21 finished
# pixel:  0 22 finished
# pixel:  0 23 finished
# pixel:  0 24 finished
# pixel:  0 25 finished
# pixel:  0 26 finished
# pixel:  0 27 finished
# pixel:  0 28 finished
# pixel:  0 29 finished
# pixel:  0 30 finished
# pixel:  0 31 finished
# pixel:  1 0 finished
# pixel:  1 1 finished
# pixel:  1 2 finished
# pixel:  1 3 finished
# pixel:  1 4 finished
# pixel:  1 5 finished
# pixel:  1 6 finished
# pixel:  1 7 finished
# pixel:  1 8 finished
# pixel:  1 9 finished
# pixel:  1 10 finished
# pixel:  1 11 finished
# pixel:  1 12 finished
# pixel:  1 13 finished
# pixel:  1 14 finished
# pixel:  1 15 finished
# pixel:  1 16 finished
# pixel:  1 17 finished
# pixel:  1 18 finished
# pixel:  1 19 finished
# pixel:  1 20 finished
# pixel:  1 21 finished
# pixel:  1 22 finished
# pixel:  1 23 finished
# pixel:  1 24 finished
# pixel:  1 25 finished
# pixel:  1 26 finished
# pixel:  1 27 finished
# pixel:  1 28 finished
# pixel:  1 29 finished
# pixel:  1 30 finished
# pixel:  1 31 finished
# pixel:  2 0 finished
# pixel:  2 1 finished
# pixel:  2 2 finished
# pixel:  2 3 finished
# pixel:  2 4 finished
# pixel:  2 5 finished
# pixel:  2 6 finished
# pixel:  2 7 finished
# pixel:  2 8 finished
# pixel:  2 9 finished
# pixel:  2 10 finished
# pixel:  2 11 finished
# pixel:  2 12 finished
# pixel:  2 13 finished
# pixel:  2 14 finished
# pixel:  2 15 finished
# pixel:  2 16 finished
# pixel:  2 17 finished
# pixel:  2 18 finished
# pixel:  2 19 finished
# pixel:  2 20 finished
# pixel:  2 21 finished
# pixel:  2 22 finished
# pixel:  2 23 finished
# pixel:  2 24 finished
# pixel:  2 25 finished
# pixel:  2 26 finished
# pixel:  2 27 finished
# pixel:  2 28 finished
# pixel:  2 29 finished
# pixel:  2 30 finished
# pixel:  2 31 finished
# pixel:  3 0 finished
# pixel:  3 1 finished
# pixel:  3 2 finished
# pixel:  3 3 finished
# pixel:  3 4 finished
# pixel:  3 5 finished
# pixel:  3 6 finished
# pixel:  3 7 finished
# pixel:  3 8 finished
# pixel:  3 9 finished
# pixel:  3 10 finished
# pixel:  3 11 finished
# pixel:  3 12 finished
# pixel:  3 13 finished
# pixel:  3 14 finished
# pixel:  3 15 finished
# pixel:  3 16 finished
# pixel:  3 17 finished
# pixel:  3 18 finished
# pixel:  3 19 finished
# pixel:  3 20 finished
# pixel:  3 21 finished
# pixel:  3 22 finished
# pixel:  3 23 finished
# pixel:  3 24 finished
# pixel:  3 25 finished
# pixel:  3 26 finished
# pixel:  3 27 finished
# pixel:  3 28 finished
# pixel:  3 29 finished
# pixel:  3 30 finished
# pixel:  3 31 finished
# pixel:  4 0 finished
# pixel:  4 1 finished
# pixel:  4 2 finished
# pixel:  4 3 finished
# pixel:  4 4 finished
# pixel:  4 5 finished
# pixel:  4 6 finished
# pixel:  4 7 finished
# pixel:  4 8 finished
# pixel:  4 9 finished
# pixel:  4 10 finished
# pixel:  4 11 finished
# pixel:  4 12 finished
# pixel:  4 13 finished
# pixel:  4 14 finished
# pixel:  4 15 finished
# pixel:  4 16 finished
# pixel:  4 17 finished
# pixel:  4 18 finished
# pixel:  4 19 finished
# pixel:  4 20 finished
# pixel:  4 21 finished
# pixel:  4 22 finished
# pixel:  4 23 finished
# pixel:  4 24 finished
# pixel:  4 25 finished
# pixel:  4 26 finished
# pixel:  4 27 finished
# pixel:  4 28 finished
# pixel:  4 29 finished
# pixel:  4 30 finished
# pixel:  4 31 finished
# pixel:  5 0 finished
# pixel:  5 1 finished
# pixel:  5 2 finished
# pixel:  5 3 finished
# pixel:  5 4 finished
# pixel:  5 5 finished
# pixel:  5 6 finished
# pixel:  5 7 finished
# pixel:  5 8 finished
# pixel:  5 9 finished
# pixel:  5 10 finished
# pixel:  5 11 finished
# pixel:  5 12 finished
# pixel:  5 13 finished
# pixel:  5 14 finished
# pixel:  5 15 finished
# pixel:  5 16 finished
# pixel:  5 17 finished
# pixel:  5 18 finished
# pixel:  5 19 finished
# pixel:  5 20 finished
# pixel:  5 21 finished
# pixel:  5 22 finished
# pixel:  5 23 finished
# pixel:  5 24 finished
# pixel:  5 25 finished
# pixel:  5 26 finished
# pixel:  5 27 finished
# pixel:  5 28 finished
# pixel:  5 29 finished
# pixel:  5 30 finished
# pixel:  5 31 finished
# pixel:  6 0 finished
# pixel:  6 1 finished
# pixel:  6 2 finished
# pixel:  6 3 finished
# pixel:  6 4 finished
# pixel:  6 5 finished
# pixel:  6 6 finished
# pixel:  6 7 finished
# pixel:  6 8 finished
# pixel:  6 9 finished
# pixel:  6 10 finished
# pixel:  6 11 finished
# pixel:  6 12 finished
# pixel:  6 13 finished
# pixel:  6 14 finished
# pixel:  6 15 finished
# pixel:  6 16 finished
# pixel:  6 17 finished
# pixel:  6 18 finished
# pixel:  6 19 finished
# pixel:  6 20 finished
# pixel:  6 21 finished
# pixel:  6 22 finished
# pixel:  6 23 finished
# pixel:  6 24 finished
# pixel:  6 25 finished
# pixel:  6 26 finished
# pixel:  6 27 finished
# pixel:  6 28 finished
# pixel:  6 29 finished
# pixel:  6 30 finished
# pixel:  6 31 finished
# pixel:  7 0 finished
# pixel:  7 1 finished
# pixel:  7 2 finished
# pixel:  7 3 finished
# pixel:  7 4 finished
# pixel:  7 5 finished
# pixel:  7 6 finished
# pixel:  7 7 finished
# pixel:  7 8 finished
# pixel:  7 9 finished
# pixel:  7 10 finished
# pixel:  7 11 finished
# pixel:  7 12 finished
# pixel:  7 13 finished
# pixel:  7 14 finished
# pixel:  7 15 finished
# pixel:  7 16 finished
# pixel:  7 17 finished
# pixel:  7 18 finished
# pixel:  7 19 finished
# pixel:  7 20 finished
# pixel:  7 21 finished
# pixel:  7 22 finished
# pixel:  7 23 finished
# pixel:  7 24 finished
# pixel:  7 25 finished
# pixel:  7 26 finished
# pixel:  7 27 finished
# pixel:  7 28 finished
# pixel:  7 29 finished
# pixel:  7 30 finished
# pixel:  7 31 finished
# pixel:  8 0 finished
# pixel:  8 1 finished
# pixel:  8 2 finished
# pixel:  8 3 finished
# pixel:  8 4 finished
# pixel:  8 5 finished
# pixel:  8 6 finished
# pixel:  8 7 finished
# pixel:  8 8 finished
# pixel:  8 9 finished
# pixel:  8 10 finished
# pixel:  8 11 finished
# pixel:  8 12 finished
# pixel:  8 13 finished
# pixel:  8 14 finished
# pixel:  8 15 finished
# pixel:  8 16 finished
# pixel:  8 17 finished
# pixel:  8 18 finished
# pixel:  8 19 finished
# pixel:  8 20 finished
# pixel:  8 21 finished
# pixel:  8 22 finished
# pixel:  8 23 finished
# pixel:  8 24 finished
# pixel:  8 25 finished
# pixel:  8 26 finished
# pixel:  8 27 finished
# pixel:  8 28 finished
# pixel:  8 29 finished
# pixel:  8 30 finished
# pixel:  8 31 finished
# pixel:  9 0 finished
# pixel:  9 1 finished
# pixel:  9 2 finished
# pixel:  9 3 finished
# pixel:  9 4 finished
# pixel:  9 5 finished
# pixel:  9 6 finished
# pixel:  9 7 finished
# pixel:  9 8 finished
# pixel:  9 9 finished
# pixel:  9 10 finished
# pixel:  9 11 finished
# pixel:  9 12 finished
# pixel:  9 13 finished
# pixel:  9 14 finished
# pixel:  9 15 finished
# pixel:  9 16 finished
# pixel:  9 17 finished
# pixel:  9 18 finished
# pixel:  9 19 finished
# pixel:  9 20 finished
# pixel:  9 21 finished
# pixel:  9 22 finished
# pixel:  9 23 finished
# pixel:  9 24 finished
# pixel:  9 25 finished
# pixel:  9 26 finished
# pixel:  9 27 finished
# pixel:  9 28 finished
# pixel:  9 29 finished
# pixel:  9 30 finished
# pixel:  9 31 finished
# pixel:  10 0 finished
# pixel:  10 1 finished
# pixel:  10 2 finished
# pixel:  10 3 finished
# pixel:  10 4 finished
# pixel:  10 5 finished
# pixel:  10 6 finished
# pixel:  10 7 finished
# pixel:  10 8 finished
# pixel:  10 9 finished
# pixel:  10 10 finished
# pixel:  10 11 finished
# pixel:  10 12 finished
# pixel:  10 13 finished
# pixel:  10 14 finished
# pixel:  10 15 finished
# pixel:  10 16 finished
# pixel:  10 17 finished
# pixel:  10 18 finished
# pixel:  10 19 finished
# pixel:  10 20 finished
# pixel:  10 21 finished
# pixel:  10 22 finished
# pixel:  10 23 finished
# pixel:  10 24 finished
# pixel:  10 25 finished
# pixel:  10 26 finished
# pixel:  10 27 finished
# pixel:  10 28 finished
# pixel:  10 29 finished
# pixel:  10 30 finished
# pixel:  10 31 finished
# pixel:  11 0 finished
# pixel:  11 1 finished
# pixel:  11 2 finished
# pixel:  11 3 finished
# pixel:  11 4 finished
# pixel:  11 5 finished
# pixel:  11 6 finished
# pixel:  11 7 finished
# pixel:  11 8 finished
# pixel:  11 9 finished
# pixel:  11 10 finished
# pixel:  11 11 finished
# pixel:  11 12 finished
# pixel:  11 13 finished
# pixel:  11 14 finished
# pixel:  11 15 finished
# pixel:  11 16 finished
# pixel:  11 17 finished
# pixel:  11 18 finished
# pixel:  11 19 finished
# pixel:  11 20 finished
# pixel:  11 21 finished
# pixel:  11 22 finished
# pixel:  11 23 finished
# pixel:  11 24 finished
# pixel:  11 25 finished
# pixel:  11 26 finished
# pixel:  11 27 finished
# pixel:  11 28 finished
# pixel:  11 29 finished
# pixel:  11 30 finished
# pixel:  11 31 finished
# pixel:  12 0 finished
# pixel:  12 1 finished
# pixel:  12 2 finished
# pixel:  12 3 finished
# pixel:  12 4 finished
# pixel:  12 5 finished
# pixel:  12 6 finished
# pixel:  12 7 finished
# pixel:  12 8 finished
# pixel:  12 9 finished
# pixel:  12 10 finished
# pixel:  12 11 finished
# pixel:  12 12 finished
# pixel:  12 13 finished
# pixel:  12 14 finished
# pixel:  12 15 finished
# pixel:  12 16 finished
# pixel:  12 17 finished
# pixel:  12 18 finished
# pixel:  12 19 finished
# pixel:  12 20 finished
# pixel:  12 21 finished
# pixel:  12 22 finished
# pixel:  12 23 finished
# pixel:  12 24 finished
# pixel:  12 25 finished
# pixel:  12 26 finished
# pixel:  12 27 finished
# pixel:  12 28 finished
# pixel:  12 29 finished
# pixel:  12 30 finished
# pixel:  12 31 finished
# pixel:  13 0 finished
# pixel:  13 1 finished
# pixel:  13 2 finished
# pixel:  13 3 finished
# pixel:  13 4 finished
# pixel:  13 5 finished
# pixel:  13 6 finished
# pixel:  13 7 finished
# pixel:  13 8 finished
# pixel:  13 9 finished
# pixel:  13 10 finished
# pixel:  13 11 finished
# pixel:  13 12 finished
# pixel:  13 13 finished
# pixel:  13 14 finished
# pixel:  13 15 finished
# pixel:  13 16 finished
# pixel:  13 17 finished
# pixel:  13 18 finished
# pixel:  13 19 finished
# pixel:  13 20 finished
# pixel:  13 21 finished
# pixel:  13 22 finished
# pixel:  13 23 finished
# pixel:  13 24 finished
# pixel:  13 25 finished
# pixel:  13 26 finished
# pixel:  13 27 finished
# pixel:  13 28 finished
# pixel:  13 29 finished
# pixel:  13 30 finished
# pixel:  13 31 finished
# pixel:  14 0 finished
# pixel:  14 1 finished
# pixel:  14 2 finished
# pixel:  14 3 finished
# pixel:  14 4 finished
# pixel:  14 5 finished
# pixel:  14 6 finished
# pixel:  14 7 finished
# pixel:  14 8 finished
# pixel:  14 9 finished
# pixel:  14 10 finished
# pixel:  14 11 finished
# pixel:  14 12 finished
# pixel:  14 13 finished
# pixel:  14 14 finished
# pixel:  14 15 finished
# pixel:  14 16 finished
# pixel:  14 17 finished
# pixel:  14 18 finished
# pixel:  14 19 finished
# pixel:  14 20 finished
# pixel:  14 21 finished
# pixel:  14 22 finished
# pixel:  14 23 finished
# pixel:  14 24 finished
# pixel:  14 25 finished
# pixel:  14 26 finished
# pixel:  14 27 finished
# pixel:  14 28 finished
# pixel:  14 29 finished
# pixel:  14 30 finished
# pixel:  14 31 finished
# pixel:  15 0 finished
# pixel:  15 1 finished
# pixel:  15 2 finished
# pixel:  15 3 finished
# pixel:  15 4 finished
# pixel:  15 5 finished
# pixel:  15 6 finished
# pixel:  15 7 finished
# pixel:  15 8 finished
# pixel:  15 9 finished
# pixel:  15 10 finished
# pixel:  15 11 finished
# pixel:  15 12 finished
# pixel:  15 13 finished
# pixel:  15 14 finished
# pixel:  15 15 finished
# pixel:  15 16 finished
# pixel:  15 17 finished
# pixel:  15 18 finished
# pixel:  15 19 finished
# pixel:  15 20 finished
# pixel:  15 21 finished
# pixel:  15 22 finished
# pixel:  15 23 finished
# pixel:  15 24 finished
# pixel:  15 25 finished
# pixel:  15 26 finished
# pixel:  15 27 finished
# pixel:  15 28 finished
# pixel:  15 29 finished
# pixel:  15 30 finished
# pixel:  15 31 finished
# pixel:  16 0 finished
# pixel:  16 1 finished
# pixel:  16 2 finished
# pixel:  16 3 finished
# pixel:  16 4 finished
# pixel:  16 5 finished
# pixel:  16 6 finished
# pixel:  16 7 finished
# pixel:  16 8 finished
# pixel:  16 9 finished
# pixel:  16 10 finished
# pixel:  16 11 finished
# pixel:  16 12 finished
# pixel:  16 13 finished
# pixel:  16 14 finished
# pixel:  16 15 finished
# pixel:  16 16 finished
# pixel:  16 17 finished
# pixel:  16 18 finished
# pixel:  16 19 finished
# pixel:  16 20 finished
# pixel:  16 21 finished
# pixel:  16 22 finished
# pixel:  16 23 finished
# pixel:  16 24 finished
# pixel:  16 25 finished
# pixel:  16 26 finished
# pixel:  16 27 finished
# pixel:  16 28 finished
# pixel:  16 29 finished
# pixel:  16 30 finished
# pixel:  16 31 finished
# pixel:  17 0 finished
# pixel:  17 1 finished
# pixel:  17 2 finished
# pixel:  17 3 finished
# pixel:  17 4 finished
# pixel:  17 5 finished
# pixel:  17 6 finished
# pixel:  17 7 finished
# pixel:  17 8 finished
# pixel:  17 9 finished
# pixel:  17 10 finished
# pixel:  17 11 finished
# pixel:  17 12 finished
# pixel:  17 13 finished
# pixel:  17 14 finished
# pixel:  17 15 finished
# pixel:  17 16 finished
# pixel:  17 17 finished
# pixel:  17 18 finished
# pixel:  17 19 finished
# pixel:  17 20 finished
# pixel:  17 21 finished
# pixel:  17 22 finished
# pixel:  17 23 finished
# pixel:  17 24 finished
# pixel:  17 25 finished
# pixel:  17 26 finished
# pixel:  17 27 finished
# pixel:  17 28 finished
# pixel:  17 29 finished
# pixel:  17 30 finished
# pixel:  17 31 finished
# pixel:  18 0 finished
# pixel:  18 1 finished
# pixel:  18 2 finished
# pixel:  18 3 finished
# pixel:  18 4 finished
# pixel:  18 5 finished
# pixel:  18 6 finished
# pixel:  18 7 finished
# pixel:  18 8 finished
# pixel:  18 9 finished
# pixel:  18 10 finished
# pixel:  18 11 finished
# pixel:  18 12 finished
# pixel:  18 13 finished
# pixel:  18 14 finished
# pixel:  18 15 finished
# pixel:  18 16 finished
# pixel:  18 17 finished
# pixel:  18 18 finished
# pixel:  18 19 finished
# pixel:  18 20 finished
# pixel:  18 21 finished
# pixel:  18 22 finished
# pixel:  18 23 finished
# pixel:  18 24 finished
# pixel:  18 25 finished
# pixel:  18 26 finished
# pixel:  18 27 finished
# pixel:  18 28 finished
# pixel:  18 29 finished
# pixel:  18 30 finished
# pixel:  18 31 finished
# pixel:  19 0 finished
# pixel:  19 1 finished
# pixel:  19 2 finished
# pixel:  19 3 finished
# pixel:  19 4 finished
# pixel:  19 5 finished
# pixel:  19 6 finished
# pixel:  19 7 finished
# pixel:  19 8 finished
# pixel:  19 9 finished
# pixel:  19 10 finished
# pixel:  19 11 finished
# pixel:  19 12 finished
# pixel:  19 13 finished
# pixel:  19 14 finished
# pixel:  19 15 finished
# pixel:  19 16 finished
# pixel:  19 17 finished
# pixel:  19 18 finished
# pixel:  19 19 finished
# pixel:  19 20 finished
# pixel:  19 21 finished
# pixel:  19 22 finished
# pixel:  19 23 finished
# pixel:  19 24 finished
# pixel:  19 25 finished
# pixel:  19 26 finished
# pixel:  19 27 finished
# pixel:  19 28 finished
# pixel:  19 29 finished
# pixel:  19 30 finished
# pixel:  19 31 finished
# pixel:  20 0 finished
# pixel:  20 1 finished
# pixel:  20 2 finished
# pixel:  20 3 finished
# pixel:  20 4 finished
# pixel:  20 5 finished
# pixel:  20 6 finished
# pixel:  20 7 finished
# pixel:  20 8 finished
# pixel:  20 9 finished
# pixel:  20 10 finished
# pixel:  20 11 finished
# pixel:  20 12 finished
# pixel:  20 13 finished
# pixel:  20 14 finished
# pixel:  20 15 finished
# pixel:  20 16 finished
# pixel:  20 17 finished
# pixel:  20 18 finished
# pixel:  20 19 finished
# pixel:  20 20 finished
# pixel:  20 21 finished
# pixel:  20 22 finished
# pixel:  20 23 finished
# pixel:  20 24 finished
# pixel:  20 25 finished
# pixel:  20 26 finished
# pixel:  20 27 finished
# pixel:  20 28 finished
# pixel:  20 29 finished
# pixel:  20 30 finished
# pixel:  20 31 finished
# pixel:  21 0 finished
# pixel:  21 1 finished
# pixel:  21 2 finished
# pixel:  21 3 finished
# pixel:  21 4 finished
# pixel:  21 5 finished
# pixel:  21 6 finished
# pixel:  21 7 finished
# pixel:  21 8 finished
# pixel:  21 9 finished
# pixel:  21 10 finished
# pixel:  21 11 finished
# pixel:  21 12 finished
# pixel:  21 13 finished
# pixel:  21 14 finished
# pixel:  21 15 finished
# pixel:  21 16 finished
# pixel:  21 17 finished
# pixel:  21 18 finished
# pixel:  21 19 finished
# pixel:  21 20 finished
# pixel:  21 21 finished
# pixel:  21 22 finished
# pixel:  21 23 finished
# pixel:  21 24 finished
# pixel:  21 25 finished
# pixel:  21 26 finished
# pixel:  21 27 finished
# pixel:  21 28 finished
# pixel:  21 29 finished
# pixel:  21 30 finished
# pixel:  21 31 finished
# pixel:  22 0 finished
# pixel:  22 1 finished
# pixel:  22 2 finished
# pixel:  22 3 finished
# pixel:  22 4 finished
# pixel:  22 5 finished
# pixel:  22 6 finished
# pixel:  22 7 finished
# pixel:  22 8 finished
# pixel:  22 9 finished
# pixel:  22 10 finished
# pixel:  22 11 finished
# pixel:  22 12 finished
# pixel:  22 13 finished
# pixel:  22 14 finished
# pixel:  22 15 finished
# pixel:  22 16 finished
# pixel:  22 17 finished
# pixel:  22 18 finished
# pixel:  22 19 finished
# pixel:  22 20 finished
# pixel:  22 21 finished
# pixel:  22 22 finished
# pixel:  22 23 finished
# pixel:  22 24 finished
# pixel:  22 25 finished
# pixel:  22 26 finished
# pixel:  22 27 finished
# pixel:  22 28 finished
# pixel:  22 29 finished
# pixel:  22 30 finished
# pixel:  22 31 finished
# pixel:  23 0 finished
# pixel:  23 1 finished
# pixel:  23 2 finished
# pixel:  23 3 finished
# pixel:  23 4 finished
# pixel:  23 5 finished
# pixel:  23 6 finished
# pixel:  23 7 finished
# pixel:  23 8 finished
# pixel:  23 9 finished
# pixel:  23 10 finished
# pixel:  23 11 finished
# pixel:  23 12 finished
# pixel:  23 13 finished
# pixel:  23 14 finished
# pixel:  23 15 finished
# pixel:  23 16 finished
# pixel:  23 17 finished
# pixel:  23 18 finished
# pixel:  23 19 finished
# pixel:  23 20 finished
# pixel:  23 21 finished
# pixel:  23 22 finished
# pixel:  23 23 finished
# pixel:  23 24 finished
# pixel:  23 25 finished
# pixel:  23 26 finished
# pixel:  23 27 finished
# pixel:  23 28 finished
# pixel:  23 29 finished
# pixel:  23 30 finished
# pixel:  23 31 finished
# pixel:  24 0 finished
# pixel:  24 1 finished
# pixel:  24 2 finished
# pixel:  24 3 finished
# pixel:  24 4 finished
# pixel:  24 5 finished
# pixel:  24 6 finished
# pixel:  24 7 finished
# pixel:  24 8 finished
# pixel:  24 9 finished
# pixel:  24 10 finished
# pixel:  24 11 finished
# pixel:  24 12 finished
# pixel:  24 13 finished
# pixel:  24 14 finished
# pixel:  24 15 finished
# pixel:  24 16 finished
# pixel:  24 17 finished
# pixel:  24 18 finished
# pixel:  24 19 finished
# pixel:  24 20 finished
# pixel:  24 21 finished
# pixel:  24 22 finished
# pixel:  24 23 finished
# pixel:  24 24 finished
# pixel:  24 25 finished
# pixel:  24 26 finished
# pixel:  24 27 finished
# pixel:  24 28 finished
# pixel:  24 29 finished
# pixel:  24 30 finished
# pixel:  24 31 finished
# pixel:  25 0 finished
# pixel:  25 1 finished
# pixel:  25 2 finished
# pixel:  25 3 finished
# pixel:  25 4 finished
# pixel:  25 5 finished
# pixel:  25 6 finished
# pixel:  25 7 finished
# pixel:  25 8 finished
# pixel:  25 9 finished
# pixel:  25 10 finished
# pixel:  25 11 finished
# pixel:  25 12 finished
# pixel:  25 13 finished
# pixel:  25 14 finished
# pixel:  25 15 finished
# pixel:  25 16 finished
# pixel:  25 17 finished
# pixel:  25 18 finished
# pixel:  25 19 finished
# pixel:  25 20 finished
# pixel:  25 21 finished
# pixel:  25 22 finished
# pixel:  25 23 finished
# pixel:  25 24 finished
# pixel:  25 25 finished
# pixel:  25 26 finished
# pixel:  25 27 finished
# pixel:  25 28 finished
# pixel:  25 29 finished
# pixel:  25 30 finished
# pixel:  25 31 finished
# pixel:  26 0 finished
# pixel:  26 1 finished
# pixel:  26 2 finished
# pixel:  26 3 finished
# pixel:  26 4 finished
# pixel:  26 5 finished
# pixel:  26 6 finished
# pixel:  26 7 finished
# pixel:  26 8 finished
# pixel:  26 9 finished
# pixel:  26 10 finished
# pixel:  26 11 finished
# pixel:  26 12 finished
# pixel:  26 13 finished
# pixel:  26 14 finished
# pixel:  26 15 finished
# pixel:  26 16 finished
# pixel:  26 17 finished
# pixel:  26 18 finished
# pixel:  26 19 finished
# pixel:  26 20 finished
# pixel:  26 21 finished
# pixel:  26 22 finished
# pixel:  26 23 finished
# pixel:  26 24 finished
# pixel:  26 25 finished
# pixel:  26 26 finished
# pixel:  26 27 finished
# pixel:  26 28 finished
# pixel:  26 29 finished
# pixel:  26 30 finished
# pixel:  26 31 finished
# pixel:  27 0 finished
# pixel:  27 1 finished
# pixel:  27 2 finished
# pixel:  27 3 finished
# pixel:  27 4 finished
# pixel:  27 5 finished
# pixel:  27 6 finished
# pixel:  27 7 finished
# pixel:  27 8 finished
# pixel:  27 9 finished
# pixel:  27 10 finished
# pixel:  27 11 finished
# pixel:  27 12 finished
# pixel:  27 13 finished
# pixel:  27 14 finished
# pixel:  27 15 finished
# pixel:  27 16 finished
# pixel:  27 17 finished
# pixel:  27 18 finished
# pixel:  27 19 finished
# pixel:  27 20 finished
# pixel:  27 21 finished
# pixel:  27 22 finished
# pixel:  27 23 finished
# pixel:  27 24 finished
# pixel:  27 25 finished
# pixel:  27 26 finished
# pixel:  27 27 finished
# pixel:  27 28 finished
# pixel:  27 29 finished
# pixel:  27 30 finished
# pixel:  27 31 finished
# pixel:  28 0 finished
# pixel:  28 1 finished
# pixel:  28 2 finished
# pixel:  28 3 finished
# pixel:  28 4 finished
# pixel:  28 5 finished
# pixel:  28 6 finished
# pixel:  28 7 finished
# pixel:  28 8 finished
# pixel:  28 9 finished
# pixel:  28 10 finished
# pixel:  28 11 finished
# pixel:  28 12 finished
# pixel:  28 13 finished
# pixel:  28 14 finished
# pixel:  28 15 finished
# pixel:  28 16 finished
# pixel:  28 17 finished
# pixel:  28 18 finished
# pixel:  28 19 finished
# pixel:  28 20 finished
# pixel:  28 21 finished
# pixel:  28 22 finished
# pixel:  28 23 finished
# pixel:  28 24 finished
# pixel:  28 25 finished
# pixel:  28 26 finished
# pixel:  28 27 finished
# pixel:  28 28 finished
# pixel:  28 29 finished
# pixel:  28 30 finished
# pixel:  28 31 finished
# pixel:  29 0 finished
# pixel:  29 1 finished
# pixel:  29 2 finished
# pixel:  29 3 finished
# pixel:  29 4 finished
# pixel:  29 5 finished
# pixel:  29 6 finished
# pixel:  29 7 finished
# pixel:  29 8 finished
# pixel:  29 9 finished
# pixel:  29 10 finished
# pixel:  29 11 finished
# pixel:  29 12 finished
# pixel:  29 13 finished
# pixel:  29 14 finished
# pixel:  29 15 finished
# pixel:  29 16 finished
# pixel:  29 17 finished
# pixel:  29 18 finished
# pixel:  29 19 finished
# pixel:  29 20 finished
# pixel:  29 21 finished
# pixel:  29 22 finished
# pixel:  29 23 finished
# pixel:  29 24 finished
# pixel:  29 25 finished
# pixel:  29 26 finished
# pixel:  29 27 finished
# pixel:  29 28 finished
# pixel:  29 29 finished
# pixel:  29 30 finished
# pixel:  29 31 finished
# pixel:  30 0 finished
# pixel:  30 1 finished
# pixel:  30 2 finished
# pixel:  30 3 finished
# pixel:  30 4 finished
# pixel:  30 5 finished
# pixel:  30 6 finished
# pixel:  30 7 finished
# pixel:  30 8 finished
# pixel:  30 9 finished
# pixel:  30 10 finished
# pixel:  30 11 finished
# pixel:  30 12 finished
# pixel:  30 13 finished
# pixel:  30 14 finished
# pixel:  30 15 finished
# pixel:  30 16 finished
# pixel:  30 17 finished
# pixel:  30 18 finished
# pixel:  30 19 finished
# pixel:  30 20 finished
# pixel:  30 21 finished
# pixel:  30 22 finished
# pixel:  30 23 finished
# pixel:  30 24 finished
# pixel:  30 25 finished
# pixel:  30 26 finished
# pixel:  30 27 finished
# pixel:  30 28 finished
# pixel:  30 29 finished
# pixel:  30 30 finished
# pixel:  30 31 finished
# pixel:  31 0 finished
# pixel:  31 1 finished
# pixel:  31 2 finished
# pixel:  31 3 finished
# pixel:  31 4 finished
# pixel:  31 5 finished
# pixel:  31 6 finished
# pixel:  31 7 finished
# pixel:  31 8 finished
# pixel:  31 9 finished
# pixel:  31 10 finished
# pixel:  31 11 finished
# pixel:  31 12 finished
# pixel:  31 13 finished
# pixel:  31 14 finished
# pixel:  31 15 finished
# pixel:  31 16 finished
# pixel:  31 17 finished
# pixel:  31 18 finished
# pixel:  31 19 finished
# pixel:  31 20 finished
# pixel:  31 21 finished
# pixel:  31 22 finished
# pixel:  31 23 finished
# pixel:  31 24 finished
# pixel:  31 25 finished
# pixel:  31 26 finished
# pixel:  31 27 finished
# pixel:  31 28 finished
# pixel:  31 29 finished
# pixel:  31 30 finished
# pixel:  31 31 finished

# %%
# 空間は局所ウィンドウのみ（x,y を広げない）
Hc, Wc = 32, 32
intercept_roi = intercept_avg[:Hc, :Wc]
weight_roi = weight_avg[:Hc, :Wc, :]
yy, xx = np.meshgrid(np.arange(Hc), np.arange(Wc), indexing="ij")

def _z_range_lo_hi(arr):
    lo = float(np.nanmin(arr))
    hi = float(np.nanmax(arr))
    if not np.isfinite(lo) or not np.isfinite(hi):
        return 0.0, 1.0
    if hi <= lo:
        hi = lo + 1e-12
    pad = 0.02 * (hi - lo)
    return lo - pad, hi + pad

z_lo, z_hi = _z_range_lo_hi(intercept_avg)

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection="3d")
surf = ax.plot_surface(
    xx, yy, intercept_roi,
    cmap="viridis", linewidth=0, antialiased=True,
    vmin=z_lo, vmax=z_hi,
)
ax.set_zlim(z_lo, z_hi)
ax.set_title("intercept_avg surface (32x32)  Z/colormap range = full image min/max")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("intercept")
fig.colorbar(surf, ax=ax, shrink=0.6, label="intercept")
plt.show()

feature_names = ["target_t", "bol_t", "pkg_t", "case_t", "sh_t", "lens_t"]
for k in range(weight_roi.shape[2]):
    z = weight_roi[:, :, k]
    w_lo, w_hi = _z_range_lo_hi(weight_avg[:, :, k])
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection="3d")
    surf = ax.plot_surface(
        xx, yy, z,
        cmap="coolwarm", linewidth=0, antialiased=True,
        vmin=w_lo, vmax=w_hi,
    )
    ax.set_zlim(w_lo, w_hi)
    name = feature_names[k] if k < len(feature_names) else k
    ax.set_title(f"weight_avg: {name} (32x32)  Z/colormap range = full image min/max")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("weight")
    fig.colorbar(surf, ax=ax, shrink=0.6, label="weight")
    plt.show()

# %%
H, W = HEIGHT, WIDTH
Hc, Wc = 32, 32
intercept_32 = intercept_avg[:Hc, :Wc]
# weight_avg が (H,W,n_features) の場合
weight_32 = weight_avg[:Hc, :Wc, :]
z_i = intercept_avg[:Hc, :Wc]  
yy, xx = np.meshgrid(np.arange(Hc), np.arange(Wc), indexing="ij")  # yy,xx: (H,W)
# --- intercept の3D分布 ---
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection="3d")
surf = ax.plot_surface(xx, yy, z_i, cmap="viridis")
ax.set_title("intercept_avg surface")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("intercept")
fig.colorbar(surf, ax=ax, shrink=0.6, label="intercept")
plt.show()
# --- weight の3D分布（各特徴量ごと） ---
feature_names = ["target_t", "bol_t", "pkg_t", "case_t", "sh_t", "lens_t"]  # 必要に応じて調整

for k in range(weight_avg.shape[2]):
    z = weight_avg[:Hc, :Wc, k]  # (H,W)
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection="3d")
    surf = ax.plot_surface(xx, yy, z, cmap="coolwarm", linewidth=0, antialiased=True)
    ax.set_title(f"weight_avg surface: {feature_names[k] if k < len(feature_names) else k}")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("weight")
    fig.colorbar(surf, ax=ax, shrink=0.6, label="weight")
    plt.show()
